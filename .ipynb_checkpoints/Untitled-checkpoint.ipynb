# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (8.12.3)
# Requirement already satisfied: numpy in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (1.24.4)
# Requirement already satisfied: ipython-genutils in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (10.4.0)
# Requirement already satisfied: traitlets<6 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipympl) (3.7.5)
# Requirement already satisfied: backcall in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: pickleshare in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (2.19.2)
# Requirement already satisfied: stack-data in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: typing-extensions in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (4.13.2)
# Requirement already satisfied: pexpect>4.3 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipython<9->ipympl) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib<4,>=3.4.0->ipympl) (3.20.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.14)
# Requirement already satisfied: six>=1.5 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from stack-data->ipython<9->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from stack-data->ipython<9->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in /home/aditya_ag00/.pyenv/versions/3.8.18/lib/python3.8/site-packages (from stack-data->ipython<9->ipympl) (0.2.3)

# %%
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.image as mpimg
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /usr/lib/python3/dist-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3648, in InteractiveShell.enable_matplotlib(self, gui)
#    3644         print('Warning: Cannot change to a different GUI toolkit: %s.'
#    3645                 ' Using %s instead.' % (gui, self.pylab_gui_select))
#    3646         gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
# -> 3648 pt.activate_matplotlib(backend)
#    3649 configure_inline_support(self, backend)
#    3651 # Now we must activate the gui pylab wants to use, and fix %run to take
#    3652 # plot updates into account
#
# File /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:368, in activate_matplotlib(backend)
#     363 # Due to circular imports, pyplot may be only partially initialised
#     364 # when this function runs.
#     365 # So avoid needing matplotlib attribute-lookup to access pyplot.
#     366 from matplotlib import pyplot as plt
# --> 368 plt.switch_backend(backend)
#     370 plt.show._needmain = False
#     371 # We need to detect at runtime whether show() is called by the user.
#     372 # For this, we wrap it into a decorator which adds a 'called' flag.
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:265, in switch_backend(newbackend)
#     262         rcParamsOrig["backend"] = "agg"
#     263         return
# --> 265 backend_mod = importlib.import_module(
#     266     cbook._backend_module_name(newbackend))
#     268 required_framework = _get_required_interactive_framework(backend_mod)
#     269 if required_framework is not None:
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'ipympl'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load your saved image
img = mpimg.imread("pca_preview.png")

coords = []

def onclick(event):
    if event.inaxes:
        x, y = int(event.xdata), int(event.ydata)
        coords.append((x, y))
        print(f"Clicked point: ({x}, {y})")
        ax.plot(x, y, 'ro')
        fig.canvas.draw()

fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(img)
ax.set_title("Click to get coordinates on PCA image")

cid = fig.canvas.mpl_connect('button_press_event', onclick)
plt.show()
